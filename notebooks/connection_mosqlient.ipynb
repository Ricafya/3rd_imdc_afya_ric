# %%
pip install mosqlient
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from mosqlient import upload_prediction

# %%
import mosqlient
print(mosqlient.__version__)
# Out:
# 2.5.2

# %%
import sys
print(sys.version)
# Out:
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]

# %%
print(api_key)
# Out:
# researchcenterafya:403c97fa-67c4-49d4-9fe5-32acdae67bb0

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv('../Demo Notebooks/.env')

api_key = os.getenv('API_KEY')

# %%
prediction_all = pd.read_csv('../src/2_model/predictions.csv')
prediction_all.head()
# Out:
#    split  uf        date  casos_real   lower_95   lower_90    lower_80  \
# 0      1  AC  2022-10-09          31   0.000000   0.000000    2.716262
# 1      1  AC  2022-10-16          38  14.469205  28.632607   40.293163
# 2      1  AC  2022-10-23          43  64.024720  71.208010   83.053925
# 3      1  AC  2022-10-30          35  75.836685  91.703804  110.695980
# 4      1  AC  2022-11-06          40  90.552820  98.444930  108.082600
#
#      lower_50       pred   upper_50   upper_80   upper_90   upper_95
# 0   30.157305   54.21307   89.29031  120.22463  133.74142  139.21107
# 1   62.227665   89.87433  112.51698  141.50285  156.95297  169.83377
# 2  101.353870  125.83045  152.43654  172.03600  189.93086  201.34988
# 3  135.996170  165.09291  196.54213  218.03484  224.63123  227.06348
# 4  136.513610  166.97636  192.10342  213.07050  228.69430  243.44300

# %%
prediction = prediction_all[(prediction_all['uf'] == 'RJ') & (prediction_all['split'] == 1)][['date', 'pred', 'lower_50', 'upper_50', 'lower_80', 'upper_80', 'lower_90', 'upper_90', 'lower_95', 'upper_95']]
prediction
# Out:
#            date        pred    lower_50    upper_50   lower_80    upper_80  \
# 884  2022-10-09   591.17970   399.76420   796.54630  183.12064   978.28326
# 885  2022-10-16   576.69020   422.80725   766.95825  228.52486   963.51830
# 886  2022-10-23   572.36584   364.35556   750.00696  143.02370   923.83606
# 887  2022-10-30   583.03265   463.23690   741.76355  319.65790   896.98610
# 888  2022-11-06   618.64087   413.40652   816.77530  223.27708   991.32635
# 889  2022-11-13   653.49880   438.32830   823.72420  302.05480   997.92650
# 890  2022-11-20   685.29456   456.30853   996.50260  314.13280  1193.00300
# 891  2022-11-27   821.02325   594.16235  1085.77300  399.76105  1292.11490
# 892  2022-12-04   933.20830   697.95105  1219.91490  500.55124  1483.71830
# 893  2022-12-11  1114.25740   826.81390  1477.92040  569.57416  1721.47510
# 894  2022-12-18  1347.73690  1033.24460  1692.56150  737.18250  2145.23240
# ...

# %%
repository = 'Ricafya/3rd_imdc_afya_ric'
description = 'LSTM Model to predict dengue cases in each uf'
commit = '0cfbbc4801bb2a7520bb48d3502563e5cfcb395e'
disease = 'A90'
adm_level = 1
adm_1 = 33
adm_2 = None
case_definition = 'probable'
published = True

# %%
res = upload_prediction(
  api_key = api_key,
  repository = repository,
  description = description,
  commit = commit,
  disease = disease,
  case_definition = case_definition,
  adm_level = adm_level,
  adm_1 = adm_1,
  published = published,
  prediction = prediction
)

print(res)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 res = upload_prediction(
#       2   api_key = api_key,
#       3   repository = repository,
#       4   description = description,
#
# File c:\Users\Marcela.Motta\AppData\Local\Programs\Python\Python312\Lib\site-packages\mosqlient\registry\_prediction_post_impl.py:96, in upload_prediction(api_key, repository, disease, description, commit, prediction, adm_level, case_definition, published, adm_0, adm_1, adm_2, adm_3)
#      93             i[field] = None
#      94     clean_prediction.append(i)
# ---> 96 return Prediction.post(
#      97     api_key=api_key,
#      98     repository=repository,
#      99     disease=disease,
#     100     description=description,
#     101     commit=commit,
#     102     case_definition=case_definition,
#     103     published=published,
# ...
